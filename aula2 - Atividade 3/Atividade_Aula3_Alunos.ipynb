# %%
import pandas as pd
import openpyxl

# %%
path = r"H:\1 - PYTHON\analise_dados\aula2\Tabela_3_Areas_gerais_de_formacao_na_graduacao.xlsx"

# %%
formacao_bruto = pd.read_excel(path, header=None)

# %%
formacao_bruto
# Out:
#                                                     0         1         2  \
# 0   Tabela 10063 - Pessoas com nível superior comp...       NaN       NaN
# 1        Brasil, Grande Região e Unidade da Federação     Total       NaN
# 2                                                 NaN     Total    Homens
# 3                                              Brasil  25854291  10478534
# 4                                               Norte   1525166    590558
# 5                                            Nordeste   4748933   1744994
# 6                                             Sudeste  12828829   5391638
# 7                                                 Sul   4338861   1768855
# 8                                        Centro-Oeste   2412502    982489
# 9                                            Rondônia    164632     62766
# 10                                               Acre     84300     33291
# 11                                           Amazonas    342566    141059
# ...

# %% [markdown]
# A tabela deverá ser dividida em 3
# - homens e mulheres por região com curso superior
# - homens e mulheres por região com curso nas áreas de Ciência, Tecnologia, Engenharias e Matemática
# - homens e mulheres por região com curso nas áreas de Educação, Serviços pessoais, Saúde e Bem-estar

# %% [markdown]
# Exemplo 1

# %%
# : = todas as linhas  |  0:4 = colunas 0, 1, 2 e 3 (as 4 primeiras)
formacao_total = formacao_bruto.iloc[3:36, 0:4].copy()

# %%
formacao_total.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres",
]

# %%
formacao_total
# Out:
#               uf_regiao     total total_homens total_mulheres
# 3                Brasil  25854291     10478534       15375757
# 4                 Norte   1525166       590558         934609
# 5              Nordeste   4748933      1744994        3003939
# 6               Sudeste  12828829      5391638        7437191
# 7                   Sul   4338861      1768855        2570005
# 8          Centro-Oeste   2412502       982489        1430013
# 9              Rondônia    164632        62766         101866
# 10                 Acre     84300        33291          51009
# 11             Amazonas    342566       141059         201507
# 12              Roraima     67045        25585          41460
# 13                 Pará    601096       229285         371811
# 14                Amapá     89191        35085          54106
# 15            Tocantins    176336        63485         112851
# 16             Maranhão    468681       161352         307329
# ...

# %%
formacao_total["percentual_mulheres"] = ((formacao_total['total_mulheres'] / formacao_total['total']) * 100).round(2)

# %%
regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]

regioesDados = formacao_total[formacao_total["uf_regiao"].isin(regioes)]

for regiaoNome in regioes:
    regiao = formacao_total.loc[formacao_total["uf_regiao"] == regiaoNome].iloc[0]
    print(f"Total de homens e mulheres com curso superior na região {regiaoNome}: {regiao["total"]}")
# Out:
# Total de homens e mulheres com curso superior na região Norte: 1525167
# Total de homens e mulheres com curso superior na região Nordeste: 4748933
# Total de homens e mulheres com curso superior na região Sudeste: 12828829
# Total de homens e mulheres com curso superior na região Sul: 4338860
# Total de homens e mulheres com curso superior na região Centro-Oeste: 2412502

# %%
formacao_total = formacao_bruto.iloc[3:36, 0:7].copy()

formacao_total.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres",
    "total_exatas",
    "total_homens_exatas",
    "total_mulheres_exatas",
]

regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]

regioesDados = formacao_total[formacao_total["uf_regiao"].isin(regioes)]

for regiaoNome in regioes:
    regiao = formacao_total.loc[formacao_total["uf_regiao"] == regiaoNome].iloc[0]
    print(f"Total de homens e mulheres com curso superior na região {regiaoNome}: {regiao["total_exatas"]}")
# Out:
# Total de homens e mulheres com curso superior na região Norte: 209657
# Total de homens e mulheres com curso superior na região Nordeste: 621388
# Total de homens e mulheres com curso superior na região Sudeste: 2328122
# Total de homens e mulheres com curso superior na região Sul: 662916
# Total de homens e mulheres com curso superior na região Centro-Oeste: 326959

# %%
formacao_total = formacao_bruto.iloc[3:36, 0:10].copy()
formacao_total.columns = [
    "uf_regiao",
    "total",
    "total_homens",
    "total_mulheres",
    "total_exatas",
    "total_homens_exatas",
    "total_mulheres_exatas",
    "total_humanas",
    "total_homens_humanas",
    "total_mulheres_humanas",
]

regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]

regioesDados = formacao_total[formacao_total["uf_regiao"].isin(regioes)]

for regiaoNome in regioes:
    regiao = formacao_total.loc[formacao_total["uf_regiao"] == regiaoNome].iloc[0]
    print(f"Total de homens e mulheres com curso superior na região {regiaoNome}: {regiao["total_humanas"]}")
# Out:
# Total de homens e mulheres com curso superior na região Norte: 599785
# Total de homens e mulheres com curso superior na região Nordeste: 1822087
# Total de homens e mulheres com curso superior na região Sudeste: 3652397
# Total de homens e mulheres com curso superior na região Sul: 1256291
# Total de homens e mulheres com curso superior na região Centro-Oeste: 749148
